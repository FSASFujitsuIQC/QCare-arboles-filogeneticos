# %%
from io import StringIO
from Bio import Phylo
from openpyxl import load_workbook
import re
import numpy as np
import os
import shutil

# %%
def import_real_tree(filename):

    # Open up the Excel file
    workbook = load_workbook(filename)
    
    # Get the first sheet
    worksheet = workbook.worksheets[0]
    
    row_list = []
    
    for r in worksheet.rows:
        column = [cell.value for cell in r]
        row_list.append(column)
    
    return(row_list)

# %%
def prune(tree):

    # substitutes string of the shape ...)NAME_OF_NODE_0001:0.1...
    # for ...):0.1... (standard format with only leave names)

    tree_nodes = re.sub(r'\)\s*[A-Za-z0-9\._]+:', '):', tree)
    tree_root = re.sub(r'\)\s*[A-Za-z0-9\._]+;', ');', tree_nodes)

    return(tree_root)

# %%
def calculate_branch_length(tree_file):

    if isinstance(tree_file, str) is True:
        tree = Phylo.read(StringIO(tree_file), 'newick')
    else:
        tree = tree_file

    lengths = [clade.branch_length for clade in tree.find_clades() if clade.branch_length is not None]

    if not lengths:
        return None, None

    mean_length = np.mean(lengths)
    std_length = np.std(lengths)

    return mean_length, std_length

# %%
file_real_trees = r'<path_to_excel_file>\file.xlsx'
directory_output = r'<path_to_output_folder>'
directory_fasta = r'<path_to_fasta_folder>'

real_tree_lists = import_real_tree(file_real_trees)

if real_tree_lists[0][0].startswith('Column'):
    real_tree_lists.pop(0)


number_list = np.linspace(0, 3, 60)

for i in range(len(number_list)-1):

    counter = 0
    print('------------------------------------')
    print(number_list[i], number_list[i+1])

    for j in range(len(real_tree_lists)):
        
        real_tree = prune(real_tree_lists[j][3])
        species = real_tree_lists[j][0]
        handle = StringIO(real_tree)
        tree = Phylo.read(handle, "newick")
        
        leaf_count = sum(1 for clade in tree.find_clades() if clade.is_terminal())

        average_branch_length, std_branch_length = calculate_branch_length(tree)

        correct_leaf_count = leaf_count<=40 and leaf_count>=10
        correct_branch_length = average_branch_length >= number_list[i] and average_branch_length < number_list[i+1]

        if correct_leaf_count and correct_branch_length and counter<5:
        
            print(j+1, f"Number of leaf nodes: {leaf_count}")
            print('Species', species)
            branch_formatted = f"{average_branch_length:.4f}".replace('.', '-')

            for filename in os.listdir(directory_fasta):
                if filename == species + '.clean.fasta':
                    src_path = os.path.join(directory_fasta, filename)
                    dst_filename = f"{branch_formatted}_{filename}"
                    dst_path = os.path.join(directory_output, dst_filename)
                    if os.path.exists(src_path):  # Only copy if source exists
                        shutil.copy(src_path, dst_path)
                    else:
                        print(f"Source file not found: {src_path}")
                    break

            counter += 1

        if counter == 5:
            break
# Out:
# ------------------------------------
# 0.0 0.05084745762711865
# 9424 Number of leaf nodes: 10
# Species Phy008O8DJ_PUCGT
# ------------------------------------
# 0.05084745762711865 0.1016949152542373
# 264 Number of leaf nodes: 14
# Species Phy008NZK8_PUCGT
# 327 Number of leaf nodes: 14
# Species Phy008O426_PUCGT
# 796 Number of leaf nodes: 40
# Species Phy008OAEB_PUCGT
# 1776 Number of leaf nodes: 38
# Species Phy008O4K3_PUCGT
# 1869 Number of leaf nodes: 12
# Species Phy008O2XD_PUCGT
# ------------------------------------
# 0.1016949152542373 0.15254237288135594
# 265 Number of leaf nodes: 19
# Species Phy008O5P7_PUCGT
# 318 Number of leaf nodes: 11
# Species Phy008NZS8_PUCGT
# 428 Number of leaf nodes: 22
# Species Phy008O3TS_PUCGT
# 440 Number of leaf nodes: 13
# Species Phy008O938_PUCGT
# 719 Number of leaf nodes: 17
# Species Phy008O4C2_PUCGT
# ------------------------------------
# 0.15254237288135594 0.2033898305084746
# 1 Number of leaf nodes: 18
# Species Phy008O9U2_PUCGT
# 75 Number of leaf nodes: 31
# Species Phy008O3QR_PUCGT
# 105 Number of leaf nodes: 29
# Species Phy008O0TK_PUCGT
# 123 Number of leaf nodes: 38
# Species Phy008O30H_PUCGT
# 132 Number of leaf nodes: 20
# Species Phy008O6FV_PUCGT
# ------------------------------------
# 0.2033898305084746 0.2542372881355932
# 5 Number of leaf nodes: 11
# Species Phy008O4KN_PUCGT
# 19 Number of leaf nodes: 17
# Species Phy008OAD8_PUCGT
# 21 Number of leaf nodes: 15
# Species Phy008O30Z_PUCGT
# 28 Number of leaf nodes: 30
# Species Phy008O85K_PUCGT
# 71 Number of leaf nodes: 18
# Species Phy008O82G_PUCGT
# ------------------------------------
# 0.2542372881355932 0.3050847457627119
# 32 Number of leaf nodes: 31
# Species Phy008O7OW_PUCGT
# 54 Number of leaf nodes: 10
# Species Phy008O7K1_PUCGT
# 59 Number of leaf nodes: 20
# Species Phy008NZ68_PUCGT
# 88 Number of leaf nodes: 17
# Species Phy008O3DR_PUCGT
# 213 Number of leaf nodes: 10
# Species Phy008NZ6B_PUCGT
# ------------------------------------
# 0.3050847457627119 0.35593220338983056
# 53 Number of leaf nodes: 12
# Species Phy008OAYW_PUCGT
# 90 Number of leaf nodes: 19
# Species Phy008NZVJ_PUCGT
# 114 Number of leaf nodes: 25
# Species Phy008O8GJ_PUCGT
# 147 Number of leaf nodes: 12
# Species Phy008O7MF_PUCGT
# 222 Number of leaf nodes: 11
# Species Phy008O7OF_PUCGT
# ------------------------------------
# 0.35593220338983056 0.4067796610169492
# 107 Number of leaf nodes: 12
# Species Phy008O7GI_PUCGT
# 151 Number of leaf nodes: 16
# Species Phy008O3XF_PUCGT
# 164 Number of leaf nodes: 22
# Species Phy008O2C9_PUCGT
# 182 Number of leaf nodes: 10
# Species Phy008O9YG_PUCGT
# 187 Number of leaf nodes: 14
# Species Phy008O3RK_PUCGT
# ------------------------------------
# 0.4067796610169492 0.4576271186440678
# 3 Number of leaf nodes: 33
# Species Phy008O0AT_PUCGT
# 36 Number of leaf nodes: 25
# Species Phy008OA3K_PUCGT
# 37 Number of leaf nodes: 11
# Species Phy008O4MW_PUCGT
# 45 Number of leaf nodes: 22
# Species Phy008O0AB_PUCGT
# 94 Number of leaf nodes: 39
# Species Phy008O4IZ_PUCGT
# ------------------------------------
# 0.4576271186440678 0.5084745762711864
# 2 Number of leaf nodes: 19
# Species Phy008NYXH_PUCGT
# 48 Number of leaf nodes: 13
# Species Phy008NZ6D_PUCGT
# 58 Number of leaf nodes: 22
# Species Phy008O6HH_PUCGT
# 69 Number of leaf nodes: 12
# Species Phy008O857_PUCGT
# 113 Number of leaf nodes: 11
# Species Phy008O4NH_PUCGT
# ------------------------------------
# 0.5084745762711864 0.5593220338983051
# 93 Number of leaf nodes: 26
# Species Phy008O5XS_PUCGT
# 99 Number of leaf nodes: 12
# Species Phy008O6LX_PUCGT
# 110 Number of leaf nodes: 12
# Species Phy008NZWD_PUCGT
# 153 Number of leaf nodes: 39
# Species Phy008O862_PUCGT
# 174 Number of leaf nodes: 10
# Species Phy008O8NY_PUCGT
# ------------------------------------
# 0.5593220338983051 0.6101694915254238
# 20 Number of leaf nodes: 10
# Species Phy008O53D_PUCGT
# 76 Number of leaf nodes: 12
# Species Phy008OAFB_PUCGT
# 85 Number of leaf nodes: 11
# Species Phy008O2MY_PUCGT
# 92 Number of leaf nodes: 28
# Species Phy008O4V3_PUCGT
# 125 Number of leaf nodes: 10
# Species Phy008O3FH_PUCGT
# ------------------------------------
# 0.6101694915254238 0.6610169491525424
# 17 Number of leaf nodes: 17
# Species Phy008O36F_PUCGT
# 60 Number of leaf nodes: 11
# Species Phy008O6SR_PUCGT
# 64 Number of leaf nodes: 10
# Species Phy008O3RO_PUCGT
# 95 Number of leaf nodes: 18
# Species Phy008O72Z_PUCGT
# 97 Number of leaf nodes: 19
# Species Phy008O970_PUCGT
# ------------------------------------
# 0.6610169491525424 0.7118644067796611
# 46 Number of leaf nodes: 14
# Species Phy008O9MW_PUCGT
# 52 Number of leaf nodes: 12
# Species Phy008O95S_PUCGT
# 87 Number of leaf nodes: 12
# Species Phy008O623_PUCGT
# 158 Number of leaf nodes: 13
# Species Phy008O2GX_PUCGT
# 193 Number of leaf nodes: 14
# Species Phy008O8SG_PUCGT
# ------------------------------------
# 0.7118644067796611 0.7627118644067797
# 31 Number of leaf nodes: 11
# Species Phy008O2A7_PUCGT
# 120 Number of leaf nodes: 17
# Species Phy008O9UT_PUCGT
# 171 Number of leaf nodes: 26
# Species Phy008O435_PUCGT
# 251 Number of leaf nodes: 36
# Species Phy008NZJ8_PUCGT
# 292 Number of leaf nodes: 11
# Species Phy008O65F_PUCGT
# ------------------------------------
# 0.7627118644067797 0.8135593220338984
# 67 Number of leaf nodes: 22
# Species Phy008O1YJ_PUCGT
# 203 Number of leaf nodes: 11
# Species Phy008NYUN_PUCGT
# 204 Number of leaf nodes: 12
# Species Phy008O4L1_PUCGT
# 346 Number of leaf nodes: 11
# Species Phy008O177_PUCGT
# 373 Number of leaf nodes: 33
# Species Phy008O4DH_PUCGT
# ------------------------------------
# 0.8135593220338984 0.864406779661017
# 6 Number of leaf nodes: 11
# Species Phy008OA1K_PUCGT
# 77 Number of leaf nodes: 17
# Species Phy008O9PK_PUCGT
# 121 Number of leaf nodes: 17
# Species Phy008O32N_PUCGT
# 152 Number of leaf nodes: 24
# Species Phy008O1GW_PUCGT
# 444 Number of leaf nodes: 29
# Species Phy008O8Q7_PUCGT
# ------------------------------------
# 0.864406779661017 0.9152542372881356
# 24 Number of leaf nodes: 11
# Species Phy008OA30_PUCGT
# 133 Number of leaf nodes: 17
# Species Phy008O95O_PUCGT
# 176 Number of leaf nodes: 15
# Species Phy008O1HS_PUCGT
# 721 Number of leaf nodes: 10
# Species Phy008O9ZE_PUCGT
# 785 Number of leaf nodes: 27
# Species Phy008NZWQ_PUCGT
# ------------------------------------
# 0.9152542372881356 0.9661016949152543
# 235 Number of leaf nodes: 12
# Species Phy008O349_PUCGT
# 391 Number of leaf nodes: 16
# Species Phy008O4KC_PUCGT
# 505 Number of leaf nodes: 24
# Species Phy008O2NS_PUCGT
# 802 Number of leaf nodes: 10
# Species Phy008O54S_PUCGT
# 1380 Number of leaf nodes: 39
# Species Phy008O8LI_PUCGT
# ------------------------------------
# 0.9661016949152543 1.0169491525423728
# 142 Number of leaf nodes: 12
# Species Phy008O9B2_PUCGT
# 1310 Number of leaf nodes: 22
# Species Phy008O3MO_PUCGT
# 1367 Number of leaf nodes: 11
# Species Phy008O9E1_PUCGT
# 1753 Number of leaf nodes: 11
# Species Phy008O8BJ_PUCGT
# 2214 Number of leaf nodes: 12
# Species Phy008O463_PUCGT
# ------------------------------------
# 1.0169491525423728 1.0677966101694916
# 348 Number of leaf nodes: 10
# Species Phy008O984_PUCGT
# 388 Number of leaf nodes: 12
# Species Phy008O9OI_PUCGT
# 1945 Number of leaf nodes: 17
# Species Phy008O4YJ_PUCGT
# 2211 Number of leaf nodes: 12
# Species Phy008O41Q_PUCGT
# 2515 Number of leaf nodes: 16
# Species Phy008NZLZ_PUCGT
# ------------------------------------
# 1.0677966101694916 1.1186440677966103
# 394 Number of leaf nodes: 12
# Species Phy008O1W5_PUCGT
# 497 Number of leaf nodes: 13
# Species Phy008O7RJ_PUCGT
# 1881 Number of leaf nodes: 15
# Species Phy008O028_PUCGT
# 1885 Number of leaf nodes: 21
# Species Phy008O1J2_PUCGT
# 2399 Number of leaf nodes: 14
# Species Phy008O8KK_PUCGT
# ------------------------------------
# 1.1186440677966103 1.1694915254237288
# 2203 Number of leaf nodes: 20
# Species Phy008O9XR_PUCGT
# 2637 Number of leaf nodes: 16
# Species Phy008OAV8_PUCGT
# 3213 Number of leaf nodes: 33
# Species Phy008NZLM_PUCGT
# 3513 Number of leaf nodes: 18
# Species Phy008O46F_PUCGT
# 4896 Number of leaf nodes: 19
# Species Phy008O8L7_PUCGT
# ------------------------------------
# 1.1694915254237288 1.2203389830508475
# 51 Number of leaf nodes: 11
# Species Phy008NZQQ_PUCGT
# 354 Number of leaf nodes: 10
# Species Phy008O6RV_PUCGT
# 2841 Number of leaf nodes: 24
# Species Phy008O4C6_PUCGT
# 3064 Number of leaf nodes: 33
# Species Phy008NZMW_PUCGT
# 3334 Number of leaf nodes: 20
# Species Phy008O7NJ_PUCGT
# ------------------------------------
# 1.2203389830508475 1.2711864406779663
# 487 Number of leaf nodes: 23
# Species Phy008O07Z_PUCGT
# 3288 Number of leaf nodes: 34
# Species Phy008OAAR_PUCGT
# 3370 Number of leaf nodes: 14
# Species Phy008O612_PUCGT
# 4605 Number of leaf nodes: 23
# Species Phy008O7HN_PUCGT
# 5834 Number of leaf nodes: 21
# Species Phy008NZXA_PUCGT
# ------------------------------------
# 1.2711864406779663 1.3220338983050848
# 4269 Number of leaf nodes: 26
# Species Phy008O8ED_PUCGT
# 4693 Number of leaf nodes: 35
# Species Phy008O1KC_PUCGT
# 7066 Number of leaf nodes: 11
# Species Phy008O0H2_PUCGT
# 7094 Number of leaf nodes: 10
# Species Phy008O5IW_PUCGT
# 8490 Number of leaf nodes: 10
# Species Phy008O7SD_PUCGT
# ------------------------------------
# 1.3220338983050848 1.3728813559322035
# 1260 Number of leaf nodes: 12
# Species Phy008O6SH_PUCGT
# 4328 Number of leaf nodes: 10
# Species Phy008O494_PUCGT
# 8193 Number of leaf nodes: 19
# Species Phy008O4YE_PUCGT
# 9194 Number of leaf nodes: 19
# Species Phy008NZHE_PUCGT
# 9763 Number of leaf nodes: 25
# Species Phy008OA6A_PUCGT
# ------------------------------------
# 1.3728813559322035 1.4237288135593222
# 1706 Number of leaf nodes: 24
# Species Phy008O56R_PUCGT
# 1840 Number of leaf nodes: 37
# Species Phy008NZSP_PUCGT
# 6206 Number of leaf nodes: 15
# Species Phy008O10T_PUCGT
# ------------------------------------
# 1.4237288135593222 1.4745762711864407
# 7307 Number of leaf nodes: 10
# Species Phy008O6DM_PUCGT
# ------------------------------------
# 1.4745762711864407 1.5254237288135595
# ------------------------------------
# 1.5254237288135595 1.576271186440678
# 199 Number of leaf nodes: 23
# Species Phy008O8KZ_PUCGT
# ------------------------------------
# 1.576271186440678 1.6271186440677967
# 1821 Number of leaf nodes: 35
# Species Phy008O1CR_PUCGT
# 2594 Number of leaf nodes: 38
# Species Phy008O8MW_PUCGT
# 5875 Number of leaf nodes: 32
# Species Phy008O5LH_PUCGT
# 7573 Number of leaf nodes: 10
# Species Phy008O77C_PUCGT
# ------------------------------------
# 1.6271186440677967 1.6779661016949154
# 790 Number of leaf nodes: 15
# Species Phy008O1ZH_PUCGT
# 7699 Number of leaf nodes: 15
# Species Phy008O32K_PUCGT
# ------------------------------------
# 1.6779661016949154 1.728813559322034
# 7130 Number of leaf nodes: 14
# Species Phy008O2EQ_PUCGT
# 10455 Number of leaf nodes: 18
# Species Phy008O7UE_PUCGT
# ------------------------------------
# 1.728813559322034 1.7796610169491527
# ------------------------------------
# 1.7796610169491527 1.8305084745762712
# 4926 Number of leaf nodes: 12
# Species Phy008O18X_PUCGT
# ------------------------------------
# 1.8305084745762712 1.88135593220339
# 1997 Number of leaf nodes: 20
# Species Phy008O40O_PUCGT
# ------------------------------------
# 1.88135593220339 1.9322033898305087
# 6953 Number of leaf nodes: 12
# Species Phy008O0F1_PUCGT
# ------------------------------------
# 1.9322033898305087 1.9830508474576272
# ------------------------------------
# 1.9830508474576272 2.0338983050847457
# ------------------------------------
# 2.0338983050847457 2.0847457627118646
# 5911 Number of leaf nodes: 34
# Species Phy008O49C_PUCGT
# ------------------------------------
# 2.0847457627118646 2.135593220338983
# ------------------------------------
# 2.135593220338983 2.1864406779661016
# ------------------------------------
# 2.1864406779661016 2.2372881355932206
# ------------------------------------
# 2.2372881355932206 2.288135593220339
# ------------------------------------
# 2.288135593220339 2.3389830508474576
# ------------------------------------
# 2.3389830508474576 2.3898305084745766
# ------------------------------------
# 2.3898305084745766 2.440677966101695
# 9366 Number of leaf nodes: 16
# Species Phy008OA2Z_PUCGT
# ------------------------------------
# 2.440677966101695 2.4915254237288136
# ------------------------------------
# 2.4915254237288136 2.5423728813559325
# ------------------------------------
# 2.5423728813559325 2.593220338983051
# ------------------------------------
# 2.593220338983051 2.6440677966101696
# ------------------------------------
# 2.6440677966101696 2.6949152542372885
# ------------------------------------
# 2.6949152542372885 2.745762711864407
# ------------------------------------
# 2.745762711864407 2.7966101694915255
# ------------------------------------
# 2.7966101694915255 2.8474576271186445
# ------------------------------------
# 2.8474576271186445 2.898305084745763
# 5728 Number of leaf nodes: 12
# Species Phy008O741_PUCGT
# ------------------------------------
# 2.898305084745763 2.9491525423728815
# ------------------------------------
# 2.9491525423728815 3.0
# 5561 Number of leaf nodes: 22
# Species Phy008O7NN_PUCGT
